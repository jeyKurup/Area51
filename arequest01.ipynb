# %% [markdown]
# # Install dependencies

# %%
# %pip install anthropic python-dotenv

# %% [markdown]
# # Load Env variable

# %%
from dotenv import load_dotenv

load_dotenv()

# %%
from anthropic import Anthropic

client = Anthropic()

model = "claude-sonnet-4-0"
max_tokens = 1000

# %% [markdown]
# # Create an api client

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)
    
    
def add_assistant_message(messages, text):
    assistent_message = {"role": "assistant", "content": text}
    messages.append(assistent_message)

# %% [markdown]
# # Make a request

# %%
# make a request

def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages= messages,
    )
    
    return message.content[0].text

# %%
messages = []
add_user_message(messages, "what is cryptocurrency, describe in one sentenece")

answer = chat(messages)

answer
# Out:
# /var/folders/76/_j8v2z9n45s8vkphwm93shfw0000gn/T/ipykernel_42063/1221245232.py:4: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(
# 'Cryptocurrency is a digital form of money that uses cryptographic technology to secure transactions and operates independently of traditional banks or governments through decentralized networks.'

# %%
add_assistant_message(messages, answer)

add_user_message(messages, "add another senetence")

answer = chat(messages)

answer
# Out:
# /var/folders/76/_j8v2z9n45s8vkphwm93shfw0000gn/T/ipykernel_42063/1221245232.py:4: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(
# 'Cryptocurrency is a digital form of money that uses cryptographic technology to secure transactions and operates independently of traditional banks or governments through decentralized networks. Bitcoin, created in 2009, was the first and remains the most well-known cryptocurrency, but thousands of others now exist, each with different features and purposes.'

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'what is cryptocurrency, describe in one sentenece'},
#  {'role': 'assistant',
#   'content': 'Cryptocurrency is a digital form of money that uses cryptographic technology to secure transactions and operates independently of traditional banks or governments through decentralized networks.'},
#  {'role': 'user', 'content': 'add another senetence'}]
